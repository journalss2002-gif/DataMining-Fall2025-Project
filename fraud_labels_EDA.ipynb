# %%
#imporing needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json("fraud_labels.json")
df.head(10)
# Out:
#    transaction_id fraud
# 0        23410063    No
# 1        23289598    No
# 2        23235120    No
# 3        22485981    No
# 4        22332853    No
# 5        23652500    No
# 6        22500112    No
# 7        23508044    No
# 8        22467943    No
# 9        23178467    No

# %%
df = df.drop(columns=["transaction_id"])

# %%
#the data type 
print("Data Types:\n", df.dtypes)
# Out:
# Data Types:
#  fraud    object
# dtype: object

# %%
print(df["fraud"].value_counts())
# Out:
# fraud
# No     775979
# Yes      1360
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
df["fraud"].value_counts().plot(kind="bar", color=["skyblue", "salmon"])
plt.title("Fraud Distribution (Yes / No)")
plt.xlabel("Fraud")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()
